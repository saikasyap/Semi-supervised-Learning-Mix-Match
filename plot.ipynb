# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
fig, ax = plt.subplots()

# Data
x = [250, 500, 1000, 2000, 4000]
y1 = [15.46, 15.46, 15.46, 15.46, 15.46]
y2 = [62.78, 36.47, 43.96, 49.83, 50.22]
y3 = [15.46, 13.0, 44.0, 43.0, 43.0]
 
# multiple line plot
plt.plot( x, y2, marker='', color='olive', linewidth=2, label = 'Entropy Min')
plt.plot( x, y1, marker='', color='black', linewidth=2, linestyle='dashed', label="supervised")
plt.plot( x, y3, marker='', color='blue', linewidth=2, label = 'Mix Match')
plt.legend(loc='upper left')

plt.ylabel("Error Scale");
plt.xlabel("Data points")
# Out:
# Text(0.5, 0, 'Data points')

# %%
print (y1)
